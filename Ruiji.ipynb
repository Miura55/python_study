# %% [markdown]
# <a href="https://colab.research.google.com/github/Miura55/python_study/blob/master/Ruiji.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone --depth 1 https://github.com/neologd/mecab-ipadic-neologd.git
# !echo yes | mecab-ipadic-neologd/bin/install-mecab-ipadic-neologd -n

# %%
# ライブラリのインポート
# %matplotlib inline
import matplotlib.pyplot as plt
import requests
import MeCab as mc
import csv

# %%
with open("out20190109.csv", "r", encoding="utf-16") as f:
    reader = csv.reader(f)
    text_lists = []
    for num in reader:
        text_lists.append(num[0])

# %%
mt = mc.Tagger("-Ochasen")
